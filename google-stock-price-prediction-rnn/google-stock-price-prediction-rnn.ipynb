# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("google-stock-price-prediction-rnn"))

# Any results you write to the current directory are saved as output.
# Out:
# ['trainset.csv', 'testset.csv']

# %%
dataset_train = pd.read_csv("google-stock-price-prediction-rnn/trainset.csv")

# %%
dataset_train
# Out:
#             Date         Open         High          Low        Close  \
# 0     2013-01-02   357.385559   361.151062   355.959839   359.288177
# 1     2013-01-03   360.122742   363.600128   358.031342   359.496826
# 2     2013-01-04   362.313507   368.339294   361.488861   366.600616
# 3     2013-01-07   365.348755   367.301056   362.929504   365.001007
# 4     2013-01-08   365.393463   365.771027   359.874359   364.280701
# ...          ...          ...          ...          ...          ...
# 1254  2017-12-22  1061.109985  1064.199951  1059.439941  1060.119995
# 1255  2017-12-26  1058.069946  1060.119995  1050.199951  1056.739990
# 1256  2017-12-27  1057.390015  1058.369995  1048.050049  1049.369995
# 1257  2017-12-28  1051.599976  1054.750000  1044.770020  1048.140015
# 1258  2017-12-29  1046.719971  1049.699951  1044.900024  1046.400024
#
#         Adj Close   Volume
# 0      359.288177  5115500
# 1      359.496826  4666500
# 2      366.600616  5562800
# 3      365.001007  3332900
# 4      364.280701  3373900
# ...           ...      ...
# 1254  1060.119995   755100
# 1255  1056.739990   760600
# 1256  1049.369995  1271900
# 1257  1048.140015   837100
# 1258  1046.400024   887500
#
# [1259 rows x 7 columns]

# %%
trainset = dataset_train.iloc[:,1:2].values

# %%
trainset
# Out:
# array([[ 357.385559],
#        [ 360.122742],
#        [ 362.313507],
#        ...,
#        [1057.390015],
#        [1051.599976],
#        [1046.719971]])

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0,1))
training_scaled = sc.fit_transform(trainset)

# %%
training_scaled
# Out:
# array([[0.01011148],
#        [0.01388614],
#        [0.01690727],
#        ...,
#        [0.97543954],
#        [0.9674549 ],
#        [0.96072522]])

# %%
x_train = []
y_train = []

# %%
for i in range(60,1259):
    x_train.append(training_scaled[i-60:i, 0])
    y_train.append(training_scaled[i,0])
x_train,y_train = np.array(x_train),np.array(y_train)

# %%
x_train.shape
# Out:
# (1199, 60)

# %%
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50,return_sequences = True,input_shape = (x_train.shape[1],1)))

# %%
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50,return_sequences = True))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50,return_sequences = True))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# %%
regressor.add(Dense(units = 1))

# %%
regressor.compile(optimizer = 'adam',loss = 'mean_squared_error')

# %%
regressor.fit(x_train,y_train,epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 17s 450ms/step - loss: 0.0397
# Epoch 2/100
# 38/38 [==============================] - 14s 371ms/step - loss: 0.0045
# Epoch 3/100
# 38/38 [==============================] - 19s 496ms/step - loss: 0.0040
# Epoch 4/100
# 38/38 [==============================] - 23s 600ms/step - loss: 0.0037
# Epoch 5/100
# 38/38 [==============================] - 18s 470ms/step - loss: 0.0036
# Epoch 6/100
# 38/38 [==============================] - 21s 554ms/step - loss: 0.0035
# Epoch 7/100
# 38/38 [==============================] - 18s 468ms/step - loss: 0.0036
# Epoch 8/100
# 38/38 [==============================] - 18s 483ms/step - loss: 0.0033
# Epoch 9/100
# 38/38 [==============================] - 19s 494ms/step - loss: 0.0033
# Epoch 10/100
# 38/38 [==============================] - 16s 433ms/step - loss: 0.0042
# Epoch 11/100
# 38/38 [==============================] - 18s 479ms/step - loss: 0.0032
# Epoch 12/100
# 38/38 [==============================] - 16s 412ms/step - loss: 0.0029
# Epoch 13/100
# 38/38 [==============================] - 20s 531ms/step - loss: 0.0030
# Epoch 14/100
# 38/38 [==============================] - 18s 468ms/step - loss: 0.0033
# Epoch 15/100
# 38/38 [==============================] - 19s 507ms/step - loss: 0.0026
# Epoch 16/100
# 38/38 [==============================] - 19s 503ms/step - loss: 0.0027
# Epoch 17/100
# 38/38 [==============================] - 18s 484ms/step - loss: 0.0028
# Epoch 18/100
# 38/38 [==============================] - 19s 496ms/step - loss: 0.0028
# Epoch 19/100
# 38/38 [==============================] - 17s 448ms/step - loss: 0.0027
# Epoch 20/100
# 38/38 [==============================] - 19s 494ms/step - loss: 0.0029
# Epoch 21/100
# 38/38 [==============================] - 22s 571ms/step - loss: 0.0029
# Epoch 22/100
# 38/38 [==============================] - 17s 449ms/step - loss: 0.0024
# Epoch 23/100
# 38/38 [==============================] - 12s 322ms/step - loss: 0.0026
# Epoch 24/100
# 38/38 [==============================] - 14s 374ms/step - loss: 0.0025
# Epoch 25/100
# 38/38 [==============================] - 15s 404ms/step - loss: 0.0025
# Epoch 26/100
# 38/38 [==============================] - 13s 342ms/step - loss: 0.0026
# Epoch 27/100
# 38/38 [==============================] - 17s 434ms/step - loss: 0.0022
# Epoch 28/100
# 38/38 [==============================] - 20s 531ms/step - loss: 0.0022
# Epoch 29/100
# 38/38 [==============================] - 21s 557ms/step - loss: 0.0023
# Epoch 30/100
# 38/38 [==============================] - 23s 595ms/step - loss: 0.0022
# Epoch 31/100
# 38/38 [==============================] - 26s 679ms/step - loss: 0.0023
# Epoch 32/100
# 38/38 [==============================] - 26s 682ms/step - loss: 0.0024
# Epoch 33/100
# 38/38 [==============================] - 22s 574ms/step - loss: 0.0019
# Epoch 34/100
# 38/38 [==============================] - 22s 570ms/step - loss: 0.0019
# Epoch 35/100
# 38/38 [==============================] - 20s 524ms/step - loss: 0.0021
# Epoch 36/100
# 38/38 [==============================] - 14s 362ms/step - loss: 0.0021
# Epoch 37/100
# 38/38 [==============================] - 16s 425ms/step - loss: 0.0023
# Epoch 38/100
# 38/38 [==============================] - 16s 428ms/step - loss: 0.0023
# Epoch 39/100
# 38/38 [==============================] - 16s 422ms/step - loss: 0.0021
# Epoch 40/100
# 38/38 [==============================] - 16s 421ms/step - loss: 0.0019
# Epoch 41/100
# 38/38 [==============================] - 16s 433ms/step - loss: 0.0021
# Epoch 42/100
# 38/38 [==============================] - 15s 403ms/step - loss: 0.0018
# Epoch 43/100
# 38/38 [==============================] - 16s 425ms/step - loss: 0.0019
# Epoch 44/100
# 38/38 [==============================] - 19s 490ms/step - loss: 0.0019
# Epoch 45/100
# 38/38 [==============================] - 20s 516ms/step - loss: 0.0019
# Epoch 46/100
# 38/38 [==============================] - 20s 517ms/step - loss: 0.0017
# Epoch 47/100
# 38/38 [==============================] - 24s 627ms/step - loss: 0.0017
# Epoch 48/100
# 38/38 [==============================] - 23s 597ms/step - loss: 0.0016
# Epoch 49/100
# 38/38 [==============================] - 23s 598ms/step - loss: 0.0018
# Epoch 50/100
# 38/38 [==============================] - 20s 525ms/step - loss: 0.0018
# Epoch 51/100
# 38/38 [==============================] - 30s 778ms/step - loss: 0.0017
# Epoch 52/100
# 38/38 [==============================] - 16s 410ms/step - loss: 0.0018
# Epoch 53/100
# 38/38 [==============================] - 10s 261ms/step - loss: 0.0020
# Epoch 54/100
# 38/38 [==============================] - 12s 305ms/step - loss: 0.0016
# Epoch 55/100
# 38/38 [==============================] - 12s 315ms/step - loss: 0.0018
# Epoch 56/100
# 38/38 [==============================] - 10s 265ms/step - loss: 0.0016
# Epoch 57/100
# 38/38 [==============================] - 6s 150ms/step - loss: 0.0018
# Epoch 58/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0017
# Epoch 59/100
# 38/38 [==============================] - 7s 189ms/step - loss: 0.0016
# Epoch 60/100
# 38/38 [==============================] - 6s 161ms/step - loss: 0.0014
# Epoch 61/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0016
# Epoch 62/100
# 38/38 [==============================] - 7s 184ms/step - loss: 0.0015
# Epoch 63/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0017
# Epoch 64/100
# 38/38 [==============================] - 7s 190ms/step - loss: 0.0015
# Epoch 65/100
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0013
# Epoch 66/100
# 38/38 [==============================] - 6s 153ms/step - loss: 0.0014
# Epoch 67/100
# 38/38 [==============================] - 6s 157ms/step - loss: 0.0017
# Epoch 68/100
# 38/38 [==============================] - 6s 152ms/step - loss: 0.0017
# Epoch 69/100
# 38/38 [==============================] - 7s 193ms/step - loss: 0.0015
# Epoch 70/100
# 38/38 [==============================] - 7s 178ms/step - loss: 0.0012
# Epoch 71/100
# 38/38 [==============================] - 7s 196ms/step - loss: 0.0013
# Epoch 72/100
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0014
# Epoch 73/100
# 38/38 [==============================] - 8s 208ms/step - loss: 0.0015
# Epoch 74/100
# 38/38 [==============================] - 7s 190ms/step - loss: 0.0014
# Epoch 75/100
# 38/38 [==============================] - 8s 206ms/step - loss: 0.0013
# Epoch 76/100
# 38/38 [==============================] - 7s 179ms/step - loss: 0.0014
# Epoch 77/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0013
# Epoch 78/100
# 38/38 [==============================] - 7s 180ms/step - loss: 0.0012
# Epoch 79/100
# 38/38 [==============================] - 7s 176ms/step - loss: 0.0013
# Epoch 80/100
# 38/38 [==============================] - 6s 151ms/step - loss: 0.0014
# Epoch 81/100
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0013
# Epoch 82/100
# 38/38 [==============================] - 7s 188ms/step - loss: 0.0013
# Epoch 83/100
# 38/38 [==============================] - 6s 151ms/step - loss: 0.0012
# Epoch 84/100
# 38/38 [==============================] - 6s 169ms/step - loss: 0.0013
# Epoch 85/100
# 38/38 [==============================] - 7s 178ms/step - loss: 0.0012
# Epoch 86/100
# 38/38 [==============================] - 7s 192ms/step - loss: 0.0012
# Epoch 87/100
# 38/38 [==============================] - 6s 154ms/step - loss: 0.0011
# Epoch 88/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0011
# Epoch 89/100
# 38/38 [==============================] - 5s 131ms/step - loss: 0.0012
# Epoch 90/100
# 38/38 [==============================] - 7s 179ms/step - loss: 0.0012
# Epoch 91/100
# 38/38 [==============================] - 7s 186ms/step - loss: 0.0010
# Epoch 92/100
# 38/38 [==============================] - 8s 205ms/step - loss: 0.0011
# Epoch 93/100
# 38/38 [==============================] - 7s 185ms/step - loss: 0.0012
# Epoch 94/100
# 38/38 [==============================] - 7s 182ms/step - loss: 0.0013
# Epoch 95/100
# 38/38 [==============================] - 6s 152ms/step - loss: 0.0011
# Epoch 96/100
# 38/38 [==============================] - 5s 137ms/step - loss: 9.6444e-04
# Epoch 97/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0011
# Epoch 98/100
# 38/38 [==============================] - 6s 148ms/step - loss: 0.0011
# Epoch 99/100
# 38/38 [==============================] - 5s 132ms/step - loss: 0.0011
# Epoch 100/100
# 38/38 [==============================] - 5s 131ms/step - loss: 0.0010

# %%
dataset_test =pd.read_csv("google-stock-price-prediction-rnn/testset.csv")

# %%
real_stock_price = dataset_test.iloc[:,1:2].values

# %%
dataset_total = pd.concat((dataset_train['Open'],dataset_test['Open']),axis = 0)
dataset_total
# Out:
# 0       357.385559
# 1       360.122742
# 2       362.313507
# 3       365.348755
# 4       365.393463
#           ...
# 120    1143.599976
# 121    1128.000000
# 122    1121.339966
# 123    1102.089966
# 124    1120.000000
# Name: Open, Length: 1384, dtype: float64

# %%
inputs = dataset_total[len(dataset_total) - len(dataset_test)-60:].values
inputs
# Out:
# array([ 955.48999 ,  966.700012,  980.      ,  980.      ,  973.719971,
#         987.450012,  992.      ,  992.099976,  990.289978,  991.77002 ,
#         986.      ,  989.440002,  989.52002 ,  970.      ,  968.369995,
#         980.      , 1009.190002, 1014.      , 1015.219971, 1017.210022,
#        1021.76001 , 1022.109985, 1028.98999 , 1027.27002 , 1030.52002 ,
#        1033.98999 , 1026.459961, 1023.419983, 1022.590027, 1019.210022,
#        1022.52002 , 1034.01001 , 1020.26001 , 1023.309998, 1035.      ,
#        1035.869995, 1040.      , 1055.089966, 1042.680054, 1022.369995,
#        1015.799988, 1012.659973,  995.940002, 1001.5     , 1020.429993,
#        1037.48999 , 1035.5     , 1039.630005, 1046.119995, 1045.      ,
#        1054.609985, 1066.079956, 1075.199951, 1071.780029, 1064.949951,
#        1061.109985, 1058.069946, 1057.390015, 1051.599976, 1046.719971,
#        1048.339966, 1064.310059, 1088.      , 1094.      , 1102.22998 ,
#        1109.400024, 1097.099976, 1106.300049, 1102.410034, 1132.51001 ,
#        1126.219971, 1131.410034, 1131.829956, 1137.48999 , 1159.849976,
#        1177.329956, 1172.530029, 1175.079956, 1176.47998 , 1167.829956,
#        1170.569946, 1162.609985, 1122.      , 1090.599976, 1027.180054,
#        1081.540039, 1055.410034, 1017.25    , 1048.      , 1045.      ,
#        1048.949951, 1079.069946, 1088.410034, 1090.569946, 1106.469971,
#        1116.189941, 1112.640015, 1127.800049, 1141.23999 , 1123.030029,
#        1107.869995, 1053.079956, 1075.140015, 1099.219971, 1089.189941,
#        1115.319946, 1136.      , 1163.849976, 1170.      , 1145.209961,
#        1149.959961, 1154.140015, 1120.01001 , 1099.      , 1092.73999 ,
#        1081.880005, 1047.030029, 1046.      , 1063.      ,  998.      ,
#        1011.630005, 1022.820007, 1013.909973,  993.409973, 1041.329956,
#        1020.      , 1016.799988, 1026.439941, 1027.98999 , 1025.040039,
#        1040.880005, 1037.      , 1051.369995, 1077.430054, 1069.400024,
#        1082.      , 1077.859985, 1052.      , 1025.52002 , 1029.51001 ,
#        1046.      , 1030.01001 , 1013.659973, 1028.099976, 1019.      ,
#        1016.900024, 1049.22998 , 1058.540039, 1058.099976, 1086.030029,
#        1093.599976, 1100.      , 1090.      , 1077.310059, 1079.890015,
#        1061.859985, 1074.060059, 1083.560059, 1065.130005, 1079.      ,
#        1079.02002 , 1064.890015, 1063.030029, 1067.560059, 1099.349976,
#        1122.329956, 1140.98999 , 1142.170044, 1131.319946, 1118.180054,
#        1118.599976, 1131.069946, 1141.119995, 1143.849976, 1148.859985,
#        1143.650024, 1158.5     , 1175.310059, 1174.849976, 1159.140015,
#        1143.599976, 1128.      , 1121.339966, 1102.089966, 1120.      ])

# %%
inputs = inputs.reshape(-1,1)

# %%
inputs
# Out:
# array([[ 955.48999 ],
#        [ 966.700012],
#        [ 980.      ],
#        [ 980.      ],
#        [ 973.719971],
#        [ 987.450012],
#        [ 992.      ],
#        [ 992.099976],
#        [ 990.289978],
#        [ 991.77002 ],
#        [ 986.      ],
#        [ 989.440002],
#        [ 989.52002 ],
#        [ 970.      ],
#        [ 968.369995],
#        [ 980.      ],
#        [1009.190002],
#        [1014.      ],
#        [1015.219971],
#        [1017.210022],
#        [1021.76001 ],
#        [1022.109985],
#        [1028.98999 ],
#        [1027.27002 ],
#        [1030.52002 ],
#        [1033.98999 ],
#        [1026.459961],
#        [1023.419983],
#        [1022.590027],
#        [1019.210022],
#        [1022.52002 ],
#        [1034.01001 ],
#        [1020.26001 ],
#        [1023.309998],
#        [1035.      ],
#        [1035.869995],
#        [1040.      ],
#        [1055.089966],
#        [1042.680054],
#        [1022.369995],
#        [1015.799988],
#        [1012.659973],
#        [ 995.940002],
#        [1001.5     ],
#        [1020.429993],
#        [1037.48999 ],
#        [1035.5     ],
#        [1039.630005],
#        [1046.119995],
#        [1045.      ],
#        [1054.609985],
#        [1066.079956],
#        [1075.199951],
#        [1071.780029],
#        [1064.949951],
#        [1061.109985],
#        [1058.069946],
#        [1057.390015],
#        [1051.599976],
#        [1046.719971],
#        [1048.339966],
#        [1064.310059],
#        [1088.      ],
#        [1094.      ],
#        [1102.22998 ],
#        [1109.400024],
#        [1097.099976],
#        [1106.300049],
#        [1102.410034],
#        [1132.51001 ],
#        [1126.219971],
#        [1131.410034],
#        [1131.829956],
#        [1137.48999 ],
#        [1159.849976],
#        [1177.329956],
#        [1172.530029],
#        [1175.079956],
#        [1176.47998 ],
#        [1167.829956],
#        [1170.569946],
#        [1162.609985],
#        [1122.      ],
#        [1090.599976],
#        [1027.180054],
#        [1081.540039],
#        [1055.410034],
#        [1017.25    ],
#        [1048.      ],
#        [1045.      ],
#        [1048.949951],
#        [1079.069946],
#        [1088.410034],
#        [1090.569946],
#        [1106.469971],
#        [1116.189941],
#        [1112.640015],
#        [1127.800049],
#        [1141.23999 ],
#        [1123.030029],
#        [1107.869995],
#        [1053.079956],
#        [1075.140015],
#        [1099.219971],
#        [1089.189941],
#        [1115.319946],
#        [1136.      ],
#        [1163.849976],
#        [1170.      ],
#        [1145.209961],
#        [1149.959961],
#        [1154.140015],
#        [1120.01001 ],
#        [1099.      ],
#        [1092.73999 ],
#        [1081.880005],
#        [1047.030029],
#        [1046.      ],
#        [1063.      ],
#        [ 998.      ],
#        [1011.630005],
#        [1022.820007],
#        [1013.909973],
#        [ 993.409973],
#        [1041.329956],
#        [1020.      ],
#        [1016.799988],
#        [1026.439941],
#        [1027.98999 ],
#        [1025.040039],
#        [1040.880005],
#        [1037.      ],
#        [1051.369995],
#        [1077.430054],
#        [1069.400024],
#        [1082.      ],
#        [1077.859985],
#        [1052.      ],
#        [1025.52002 ],
#        [1029.51001 ],
#        [1046.      ],
#        [1030.01001 ],
#        [1013.659973],
#        [1028.099976],
#        [1019.      ],
#        [1016.900024],
#        [1049.22998 ],
#        [1058.540039],
#        [1058.099976],
#        [1086.030029],
#        [1093.599976],
#        [1100.      ],
#        [1090.      ],
#        [1077.310059],
#        [1079.890015],
#        [1061.859985],
#        [1074.060059],
#        [1083.560059],
#        [1065.130005],
#        [1079.      ],
#        [1079.02002 ],
#        [1064.890015],
#        [1063.030029],
#        [1067.560059],
#        [1099.349976],
#        [1122.329956],
#        [1140.98999 ],
#        [1142.170044],
#        [1131.319946],
#        [1118.180054],
#        [1118.599976],
#        [1131.069946],
#        [1141.119995],
#        [1143.849976],
#        [1148.859985],
#        [1143.650024],
#        [1158.5     ],
#        [1175.310059],
#        [1174.849976],
#        [1159.140015],
#        [1143.599976],
#        [1128.      ],
#        [1121.339966],
#        [1102.089966],
#        [1120.      ]])

# %%
inputs = sc.transform(inputs)
inputs.shape
# Out:
# (185, 1)

# %%
x_test = []
for i in range(60,185):
    x_test.append(inputs[i-60:i,0])

# %%
x_test = np.array(x_test)
x_test.shape
# Out:
# (125, 60)

# %%
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
x_test.shape
# Out:
# (125, 60, 1)

# %%
predicted_price = regressor.predict(x_test)

# %%
predicted_price = sc.inverse_transform(predicted_price)
predicted_price
# Out:
# array([[1071.8737],
#        [1070.286 ],
#        [1071.8082],
#        [1078.8212],
#        [1089.3254],
#        [1100.2252],
#        [1109.3318],
#        [1113.6094],
#        [1114.6724],
#        [1113.9174],
#        [1116.6779],
#        [1122.1017],
#        [1128.4893],
#        [1133.9573],
#        [1138.2659],
#        [1144.1284],
#        [1153.0863],
#        [1162.097 ],
#        [1168.9559],
#        [1173.088 ],
#        [1173.9552],
#        [1173.2432],
#        [1171.5686],
#        [1165.108 ],
#        [1152.2373],
#        [1130.0348],
#        [1111.3793],
#        [1099.7651],
#        [1090.5004],
#        [1085.8478],
#        [1085.1587],
#        [1086.7948],
#        [1092.3463],
#        [1100.6099],
#        [1108.3757],
#        [1115.111 ],
#        [1120.9707],
#        [1124.7612],
#        [1128.1626],
#        [1133.055 ],
#        [1136.2836],
#        [1135.151 ],
#        [1124.3357],
#        [1110.8148],
#        [1103.6824],
#        [1103.5596],
#        [1110.7944],
#        [1123.6504],
#        [1140.2369],
#        [1155.9076],
#        [1163.5381],
#        [1163.7998],
#        [1160.7494],
#        [1153.5945],
#        [1142.6174],
#        [1130.833 ],
#        [1120.5164],
#        [1109.4526],
#        [1098.8759],
#        [1092.9636],
#        [1084.2166],
#        [1073.8118],
#        [1065.9341],
#        [1061.0444],
#        [1055.8384],
#        [1055.7241],
#        [1057.7493],
#        [1058.6482],
#        [1058.5475],
#        [1057.979 ],
#        [1056.8165],
#        [1057.2727],
#        [1058.7722],
#        [1062.1008],
#        [1069.5477],
#        [1077.7726],
#        [1085.3777],
#        [1090.3837],
#        [1089.1506],
#        [1080.0784],
#        [1068.0026],
#        [1060.1146],
#        [1056.6528],
#        [1054.1893],
#        [1053.3168],
#        [1052.7183],
#        [1051.552 ],
#        [1054.0214],
#        [1060.86  ],
#        [1068.9507],
#        [1078.727 ],
#        [1088.8984],
#        [1097.8356],
#        [1102.6901],
#        [1101.9213],
#        [1098.056 ],
#        [1091.8549],
#        [1087.2845],
#        [1087.251 ],
#        [1088.5999],
#        [1091.2037],
#        [1094.2208],
#        [1094.9283],
#        [1093.0338],
#        [1090.4935],
#        [1092.7747],
#        [1102.3044],
#        [1117.3163],
#        [1132.082 ],
#        [1140.8386],
#        [1141.406 ],
#        [1136.8239],
#        [1132.8433],
#        [1133.2731],
#        [1137.8661],
#        [1144.6337],
#        [1150.2716],
#        [1155.2648],
#        [1161.4644],
#        [1167.8507],
#        [1170.9615],
#        [1168.825 ],
#        [1161.7935],
#        [1152.6925],
#        [1142.733 ]], dtype=float32)

# %%
plt.plot(real_stock_price,color = 'red', label = 'Real Price')
plt.plot(predicted_price, color = 'blue', label = 'Predicted Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
